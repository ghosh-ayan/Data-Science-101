# %%
# %matplotlib inline
import pandas as pd

# %%
imdb_df = pd.read_csv('https://datasets.imdbws.com/name.basics.tsv.gz', compression='gzip', 
                         header=0, sep='\t', quotechar='"', nrows=10)
imdb_df
# Out:
#       nconst      primaryName  birthYear deathYear  \
# 0  nm0000001     Fred Astaire       1899      1987
# 1  nm0000002    Lauren Bacall       1924      2014
# 2  nm0000003  Brigitte Bardot       1934        \N
# 3  nm0000004     John Belushi       1949      1982
# 4  nm0000005   Ingmar Bergman       1918      2007
# 5  nm0000006   Ingrid Bergman       1915      1982
# 6  nm0000007  Humphrey Bogart       1899      1957
# 7  nm0000008    Marlon Brando       1924      2004
# 8  nm0000009   Richard Burton       1925      1984
# 9  nm0000010     James Cagney       1899      1986
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
# 5          actress,soundtrack,producer
# 6            actor,soundtrack,producer
# 7            actor,soundtrack,director
# ...

# %%
title_akas_df = pd.read_csv('https://datasets.imdbws.com/title.akas.tsv.gz', compression='gzip', 
                         header=0, sep='\t', quotechar='"', nrows=10)
title_akas_df
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
# 5  tt0000001         6                 Carmencita     US       \N
# 6  tt0000001         7                 Carmencita     \N       \N
# 7  tt0000001         8                    カルメンチータ     JP       ja
# 8  tt0000002         1     Le clown et ses chiens     \N       \N
# 9  tt0000002         2          A bohóc és kutyái     HU       \N
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay             \N                0
# 1           \N  literal title                0
# 2  imdbDisplay             \N                0
# 3  imdbDisplay             \N                0
# ...

# %%
title_akas_df.columns
# Out:
# Index(['titleId', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'isOriginalTitle'],
#       dtype='object')

# %%
len(title_akas_df)
# Out:
# 10

# %%
title_akas_df.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay             \N                0
# 1           \N  literal title                0
# 2  imdbDisplay             \N                0
# 3  imdbDisplay             \N                0
# 4  imdbDisplay             \N                0

# %%
testdf = title_akas_df
print(id(title_akas_df))
print(id(testdf))
testdf = testdf.set_index('ordering')
testdf
# Out:
# 1552750999816
# 1552750999816
#             titleId                      title region language        types  \
# ordering
# 1         tt0000001                 Карменсіта     UA       \N  imdbDisplay
# 2         tt0000001                 Carmencita     DE       \N           \N
# 3         tt0000001  Carmencita - spanyol tánc     HU       \N  imdbDisplay
# 4         tt0000001                 Καρμενσίτα     GR       \N  imdbDisplay
# 5         tt0000001                 Карменсита     RU       \N  imdbDisplay
# 6         tt0000001                 Carmencita     US       \N           \N
# 7         tt0000001                 Carmencita     \N       \N     original
# 8         tt0000001                    カルメンチータ     JP       ja  imdbDisplay
# 1         tt0000002     Le clown et ses chiens     \N       \N     original
# 2         tt0000002          A bohóc és kutyái     HU       \N  imdbDisplay
#
#              attributes  isOriginalTitle
# ordering
# ...

# %%
print(id(title_akas_df))
print(id(testdf))
# Out:
# 1552750999816
# 1552751035272

# %%
title_akas_df.loc[2]
# Out:
# titleId                            tt0000001
# ordering                                   3
# title              Carmencita - spanyol tánc
# region                                    HU
# language                                  \N
# types                            imdbDisplay
# attributes                                \N
# isOriginalTitle                            0
# Name: 2, dtype: object

# %%
type(testdf.loc[2])
# Out:
# pandas.core.frame.DataFrame
